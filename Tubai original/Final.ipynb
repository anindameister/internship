# %%
import pandas as pd
import math
df = pd.read_csv('H:\my university files\internship now\github\jonathan output file\imageHasOnLeftRightCenterTopBottom.csv')

# %%
confidence_score=[]
diagonal_object_values=[]
X_Image_Dimentions_values=[]
Y_Image_Dimentions_values=[]
x1_values=[]
x2_values=[]
y1_values=[]
y2_values=[] 
x_values = [] 
object_name_list=[]
Image_name_list=[]
y_values=[]


for _,row in df.iterrows():

    x_values.append(row['X-centre'])
    object_name_list.append(row['object name'])
    Image_name_list.append(row['Image name'])
    y_values.append(row['Y-centre'])
    diagonal_object_values.append(row['diagonal object'])
    x1_values.append(row['X1'])
    x2_values.append(row['X2'])
    y1_values.append(row['Y1'])
    y2_values.append(row['Y2'])
    X_Image_Dimentions_values.append(row['X-Image Dimentions'])
    Y_Image_Dimentions_values.append(row['Y-Image Dimentions'])
    confidence_score.append(row['confidence'])

# %%
relations=["is close to","is far from","is greater than","is smaller than","overlaps","doesn't overlap","is in the right of",
           "is in the left of","is in the bottom of","is in the top of","in between"]
predicate = []
object_1 = []
object_2 = []
imageName = []
for i in range(len(y_values)):
    for j in range(i + 1, len(y_values)):
        if ((diagonal_object_values[i]+diagonal_object_values[j])/2)>(math.sqrt((x_values[i]-x_values[j])**2)+(y_values[i]-y_values[j])**2) and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is far from",object_name_list[j],"in the",Image_name_list[i])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[1])
            object_2.append(object_name_list[j])
            
            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[1])
            object_2.append(object_name_list[i])            
        elif ((diagonal_object_values[i]+diagonal_object_values[j])/2)<(math.sqrt((x_values[i]-x_values[j])**2)+(y_values[i]-y_values[j])**2) and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is close to",object_name_list[j],"in the",Image_name_list[i])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[0])
            object_2.append(object_name_list[j])
            
            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[0])
            object_2.append(object_name_list[i])

# %%
for i in range(len(y_values)):
    for j in range(i + 1, len(y_values)):    
        if ((y1_values[i]-y2_values[i])*(x1_values[i]-x2_values[i]))>((y1_values[j]-y2_values[j])*(x1_values[j]-x2_values[j])) and Image_name_list[i]==Image_name_list[j]:
#            print(object_name_list[i],"is greater than",object_name_list[j])
#            print(object_name_list[j],"is smaller than",object_name_list[i])
           object_1.append(object_name_list[i]) 
           imageName.append(Image_name_list[i])
           predicate.append(relations[2])
           object_2.append(object_name_list[j])

           object_1.append(object_name_list[j]) 
           imageName.append(Image_name_list[j])
           predicate.append(relations[3])
           object_2.append(object_name_list[i])
            
        elif ((y1_values[i]-y2_values[i])*(x1_values[i]-x2_values[i]))<((y1_values[j]-y2_values[j])*(x1_values[j]-x2_values[j])) and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is smaller than",object_name_list[j])
#             print(object_name_list[j],"is greater than",object_name_list[i])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[3])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[2])
            object_2.append(object_name_list[i])

# %%
from shapely.geometry import Polygon
for i in range(len(y_values)):
    for j in range(i + 1, len(y_values)): 
        p1=Polygon([(x1_values[i],y1_values[i]),(x2_values[i],y2_values[i]),(x1_values[i],y2_values[i]),(x2_values[i],y1_values[i])])
        p2=Polygon([(x1_values[j],y1_values[j]),(x2_values[j],y2_values[j]),(x1_values[j],y2_values[j]),(x2_values[j],y1_values[j])])
        if p1.intersects(p2)==True and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"overlaps",object_name_list[j])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[4])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[4])
            object_2.append(object_name_list[i])            
        elif p1.intersects(p2)==False and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"doesn't overlap",object_name_list[j])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[5])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[5])
            object_2.append(object_name_list[i])

# %%
for i in range(len(x_values)):
    for j in range(i + 1, len(x_values)):
        if x_values[i]>x_values[j] and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is in the right of",object_name_list[j])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[6])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[7])
            object_2.append(object_name_list[i])
        elif x_values[i]<x_values[j] and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is in the left of",object_name_list[j])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[7])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[6])
            object_2.append(object_name_list[i])

# %%
for i in range(len(x_values)):
    for j in range(i + 1, len(x_values)):
        for k in range(j + 1, len(x_values)):
            if x_values[k]<x_values[i]<x_values[j] and Image_name_list[i]==Image_name_list[j]==Image_name_list[k]:
#                 print(object_name_list[i],"is in between of",object_name_list[k],"and",object_name_list[j])
                object_1.append(object_name_list[i]) 
                imageName.append(Image_name_list[i])
                predicate.append(relations[10])
#           relations.append(f'object {x_values.index(current_element)} is to the left of object {x_values.index(new_element)}')
                object_2.append(f' {(object_name_list[k])},{(object_name_list[j])}')
                
            elif x_values[j]<x_values[i]<x_values[k] and Image_name_list[i]==Image_name_list[j]==Image_name_list[k]:
#                 print(object_name_list[i],"is in between of",object_name_list[j],"and",object_name_list[k])
                object_1.append(object_name_list[i]) 
                imageName.append(Image_name_list[i])
                predicate.append(relations[10])
                object_2.append(f' {(object_name_list[j])},{(object_name_list[k])}')
            elif x_values[i]<x_values[j]<x_values[k] and Image_name_list[i]==Image_name_list[j]==Image_name_list[k]:
#                 print(object_name_list[j],"is in between of",object_name_list[i],"and",object_name_list[k])
                object_1.append(object_name_list[j]) 
                imageName.append(Image_name_list[i])
                predicate.append(relations[10])
                object_2.append(f' {(object_name_list[i])},{(object_name_list[k])}')
            elif x_values[k]<x_values[j]<x_values[i] and Image_name_list[i]==Image_name_list[j]==Image_name_list[k]:
#                 print(object_name_list[j],"is in between of",object_name_list[k],"and",object_name_list[i])
                object_1.append(object_name_list[j]) 
                imageName.append(Image_name_list[i])
                predicate.append(relations[10])
                object_2.append(f' {(object_name_list[k])},{(object_name_list[i])}') 
            elif x_values[i]<x_values[k]<x_values[j] and Image_name_list[i]==Image_name_list[j]==Image_name_list[k]:
#                 print(object_name_list[k],"is in between of",object_name_list[j],"and",object_name_list[i])
                object_1.append(object_name_list[k]) 
                imageName.append(Image_name_list[i])
                predicate.append(relations[10])
                object_2.append(f' {(object_name_list[i])},{(object_name_list[j])}')
            elif x_values[j]<x_values[k]<x_values[i] and Image_name_list[i]==Image_name_list[j]==Image_name_list[k]:
#                 print(object_name_list[k],"is in between of",object_name_list[j],"and",object_name_list[i])  
                object_1.append(object_name_list[k]) 
                imageName.append(Image_name_list[i])
                predicate.append(relations[10])
                object_2.append(f' {(object_name_list[j])},{(object_name_list[i])}')

# %%
for i in range(len(x_values)):
    for j in range(i + 1, len(x_values)):
        if y_values[i]>y_values[j] and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is in the bottom of",object_name_list[j])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[8])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[9])
            object_2.append(object_name_list[i])            
        elif y_values[i]<y_values[j] and Image_name_list[i]==Image_name_list[j]:
#             print(object_name_list[i],"is in the top of",object_name_list[j])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[9])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[8])
            object_2.append(object_name_list[i])

# %%
af = pd.DataFrame(data={"object_1": object_1, "relations": predicate, "object_2": object_2,"image_Name":imageName})
af.to_csv("./Final3objects.csv", sep=',',index=False)
