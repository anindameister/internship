# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-09e0d6a18c6e> in <module>
#       1 import pandas as pd
#       2 import math
# ----> 3 df = pd.read_csv('H:\my university files\internship now\github\jonathan output file\10.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# .csv does not exist: 'H:\\my university files\\internship now\\github\\jonathan output file\x08.csv'

# %%
diagonal_object_values=[]
X_Image_Dimentions_values=[]
Y_Image_Dimentions_values=[]
x1_values=[]
x2_values=[]
y1_values=[]
y2_values=[]
x_values = [] 
object_name_list=[]
Image_name_list=[]
y_values=[]


for _,row in df.iterrows():

    x_values.append(row['X-centre'])
    object_name_list.append(row['object name'])
    Image_name_list.append(row['Image name'])
    y_values.append(row['Y-centre'])
    diagonal_object_values.append(row['diagonal object'])
    x1_values.append(row['X1'])
    x2_values.append(row['X2'])
    y1_values.append(row['Y1'])
    y2_values.append(row['Y2'])
    X_Image_Dimentions_values.append(row['X-Image Dimentions'])
    Y_Image_Dimentions_values.append(row['Y-Image Dimentions'])

# %%
for i in range(len(y_values)):
    for j in range(i + 1, len(y_values)):    
        if ((y1_values[i]-y2_values[i])*(x1_values[i]-x2_values[i]))>((y1_values[j]-y2_values[j])*(x1_values[j]-x2_values[j])) and Image_name_list[i]==Image_name_list[j]:
           print(object_name_list[i],"is greater than",object_name_list[j])
           print(object_name_list[j],"is smaller than",object_name_list[i])
           object_1.append(object_name_list[i]) 
           imageName.append(Image_name_list[i])
           predicate.append(relations[2])
           object_2.append(object_name_list[j])

           object_1.append(object_name_list[j]) 
           imageName.append(Image_name_list[j])
           predicate.append(relations[3])
           object_2.append(object_name_list[i])
            
        elif ((y1_values[i]-y2_values[i])*(x1_values[i]-x2_values[i]))<((y1_values[j]-y2_values[j])*(x1_values[j]-x2_values[j])) and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"is smaller than",object_name_list[j])
            print(object_name_list[j],"is greater than",object_name_list[i])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[3])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[2])
            object_2.append(object_name_list[i])
# Out:
# cat is greater than cup
# cup is smaller than cat
# cat is smaller than dining table
# dining table is greater than cat
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is smaller than cow
# cow is greater than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is greater than cow
# cow is smaller than elephant
# elephant is greater than cow
# cow is smaller than elephant
# elephant is smaller than cow
# cow is greater than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is smaller than elephant
# elephant is greater than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# cow is greater than elephant
# elephant is smaller than cow
# cow is greater than cow
# cow is smaller than cow
# cow is greater than cow
# cow is smaller than cow
# cow is greater than cow
# cow is smaller than cow
# cow is greater than elephant
# elephant is smaller than cow
# cow is smaller than elephant
# elephant is greater than cow
# cow is greater than elephant
# elephant is smaller than cow
# elephant is smaller than cow
# cow is greater than elephant
# elephant is greater than cow
# cow is smaller than elephant
# elephant is smaller than cow
# cow is greater than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is smaller than elephant
# elephant is greater than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# cow is greater than cow
# cow is smaller than cow
# cow is smaller than cow
# cow is greater than cow
# cow is greater than elephant
# elephant is smaller than cow
# cow is smaller than elephant
# elephant is greater than cow
# cow is greater than elephant
# elephant is smaller than cow
# cow is smaller than cow
# cow is greater than cow
# cow is smaller than elephant
# elephant is greater than cow
# cow is smaller than elephant
# elephant is greater than cow
# cow is greater than elephant
# elephant is smaller than cow
# cow is greater than elephant
# elephant is smaller than cow
# cow is smaller than elephant
# elephant is greater than cow
# cow is greater than elephant
# elephant is smaller than cow
# elephant is smaller than elephant
# elephant is greater than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# elephant is greater than car
# car is smaller than elephant
# elephant is greater than elephant
# elephant is smaller than elephant
# car is smaller than elephant
# elephant is greater than car
# car is smaller than dog
# dog is greater than car
# elephant is greater than car
# car is smaller than elephant
# car is greater than car
# car is smaller than car
# person is smaller than car
# car is greater than person
# bus is greater than traffic light
# traffic light is smaller than bus
# bus is greater than person
# person is smaller than bus
# elephant is smaller than truck
# truck is greater than elephant
# elephant is greater than car
# car is smaller than elephant
# elephant is smaller than truck
# truck is greater than elephant
# elephant is greater than car
# car is smaller than elephant
# truck is greater than car
# car is smaller than truck
# truck is smaller than truck
# truck is greater than truck
# truck is greater than car
# car is smaller than truck
# car is smaller than truck
# truck is greater than car
# car is smaller than car
# car is greater than car
# truck is greater than car
# car is smaller than truck
# person is smaller than car
# car is greater than person
# person is smaller than elephant
# elephant is greater than person
# person is greater than person
# person is smaller than person
# person is greater than person
# person is smaller than person
# person is greater than person
# person is smaller than person
# car is smaller than elephant
# elephant is greater than car
# car is greater than person
# person is smaller than car
# car is greater than person
# person is smaller than car
# car is greater than person
# person is smaller than car
# elephant is greater than person
# person is smaller than elephant
# elephant is greater than person
# person is smaller than elephant
# elephant is greater than person
# person is smaller than elephant
# person is greater than person
# person is smaller than person
# person is greater than person
# person is smaller than person
# person is greater than person
# person is smaller than person

# %%
for i in range(len(y_values)):
    for j in range(i + 1, len(y_values)):
        if ((diagonal_object_values[i]+diagonal_object_values[j])/2)>(math.sqrt((x_values[i]-x_values[j])**2)+(y_values[i]-y_values[j])**2):
           print(object_name_list[i],"is close to",object_name_list[j],"in the image",Image_name_list[i])
           mean_of_diagonal_objects[object_name_list[i],object_name_list[j]]=diagonal_object_values[i]+diagonal_object_values[j])/2
           distance_between_objects=math.sqrt((x_values[i]-x_values[j])**2)+(y_values[i]-y_values[j])**2
           print(mean_of_diagonal_objects,"between",object_name_list[i],"and",object_name_list[j],"in the image is",Image_name_list[i])
        else:
            print(object_name_list[i],"is far from",object_name_list[j]"in the image",Image_name_list[i])
            print(mean_of_diagonal_objects,"between",object_name_list[i],"and",object_name_list[j],"in the image is",Image_name_list[i])
# Out:
#   File "<ipython-input-59-86e43425ed48>", line 5
#     mean_of_diagonal_objects[object_name_list[i],object_name_list[j]]=diagonal_object_values[i]+diagonal_object_values[j])/2
#                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
from shapely.geometry import Polygon
for i in range(len(y_values)):
    for j in range(i + 1, len(y_values)): 
        p1=Polygon([(x1_values[i],y1_values[i]),(x2_values[i],y2_values[i]),(x1_values[i],y2_values[i]),(x2_values[i],y1_values[i])])
        p2=Polygon([(x1_values[j],y1_values[j]),(x2_values[j],y2_values[j]),(x1_values[j],y2_values[j]),(x2_values[j],y1_values[j])])
        if p1.intersects(p2)==True and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"overlaps",object_name_list[j])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[4])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[4])
            object_2.append(object_name_list[i])            
        elif p1.intersects(p2)==False and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"doesn't overlap",object_name_list[j])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[5])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[5])
            object_2.append(object_name_list[i])
# Out:
# cat overlaps cup
# cat overlaps dining table
# elephant overlaps elephant
# elephant doesn't overlap cow
# elephant doesn't overlap elephant
# elephant doesn't overlap cow
# elephant doesn't overlap cow
# elephant overlaps cow
# elephant doesn't overlap elephant
# elephant doesn't overlap elephant
# elephant doesn't overlap elephant
# cow doesn't overlap elephant
# cow doesn't overlap cow
# cow doesn't overlap cow
# cow doesn't overlap cow
# cow overlaps elephant
# cow overlaps elephant
# cow doesn't overlap elephant
# elephant doesn't overlap cow
# elephant doesn't overlap cow
# elephant overlaps cow
# elephant doesn't overlap elephant
# elephant doesn't overlap elephant
# elephant doesn't overlap elephant
# cow doesn't overlap cow
# cow doesn't overlap cow
# cow overlaps elephant
# cow doesn't overlap elephant
# cow doesn't overlap elephant
# cow doesn't overlap cow
# cow doesn't overlap elephant
# cow doesn't overlap elephant
# cow overlaps elephant
# cow doesn't overlap elephant
# cow doesn't overlap elephant
# cow doesn't overlap elephant
# elephant overlaps elephant
# elephant doesn't overlap elephant
# elephant overlaps elephant
# elephant overlaps elephant
# elephant overlaps car
# elephant overlaps elephant
# car overlaps elephant
# car overlaps dog
# elephant overlaps car
# car doesn't overlap car
# person doesn't overlap car
# bus doesn't overlap traffic light
# bus doesn't overlap person
# elephant overlaps truck
# elephant overlaps car
# elephant overlaps truck
# elephant overlaps car
# truck overlaps car
# truck overlaps truck
# truck overlaps car
# car overlaps truck
# car overlaps car
# truck overlaps car
# person overlaps car
# person overlaps elephant
# person doesn't overlap person
# person doesn't overlap person
# person doesn't overlap person
# car overlaps elephant
# car doesn't overlap person
# car overlaps person
# car overlaps person
# elephant doesn't overlap person
# elephant doesn't overlap person
# elephant doesn't overlap person
# person doesn't overlap person
# person doesn't overlap person
# person overlaps person

# %%
for i in range(len(x_values)):
    for j in range(i + 1, len(x_values)):
        if x_values[i]>x_values[j] and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"is in the right of",object_name_list[j])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[6])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[7])
            object_2.append(object_name_list[i])
        elif x_values[i]<x_values[j] and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"is in the left of",object_name_list[j])
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[7])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[6])
            object_2.append(object_name_list[i])
# Out:
# cat is in the right of cup
# cat is in the left of dining table
# elephant is in the right of elephant
# elephant is in the right of cow
# elephant is in the left of elephant
# elephant is in the right of cow
# elephant is in the right of cow
# elephant is in the left of cow
# elephant is in the right of elephant
# elephant is in the right of elephant
# elephant is in the right of elephant
# cow is in the left of elephant
# cow is in the right of cow
# cow is in the left of cow
# cow is in the left of cow
# cow is in the right of elephant
# cow is in the left of elephant
# cow is in the left of elephant
# elephant is in the right of cow
# elephant is in the right of cow
# elephant is in the right of cow
# elephant is in the right of elephant
# elephant is in the right of elephant
# elephant is in the right of elephant
# cow is in the left of cow
# cow is in the left of cow
# cow is in the left of elephant
# cow is in the left of elephant
# cow is in the left of elephant
# cow is in the left of cow
# cow is in the right of elephant
# cow is in the right of elephant
# cow is in the right of elephant
# cow is in the right of elephant
# cow is in the right of elephant
# cow is in the right of elephant
# elephant is in the left of elephant
# elephant is in the left of elephant
# elephant is in the left of elephant
# elephant is in the left of elephant
# elephant is in the left of car
# elephant is in the left of elephant
# car is in the right of elephant
# car is in the right of dog
# elephant is in the right of car
# car is in the left of car
# person is in the right of car
# bus is in the right of traffic light
# bus is in the left of person
# elephant is in the right of truck
# elephant is in the left of car
# elephant is in the right of truck
# elephant is in the left of car
# truck is in the left of car
# truck is in the right of truck
# truck is in the left of car
# car is in the right of truck
# car is in the right of car
# truck is in the left of car
# person is in the right of car
# person is in the right of elephant
# person is in the left of person
# person is in the right of person
# person is in the right of person
# car is in the left of elephant
# car is in the left of person
# car is in the right of person
# car is in the right of person
# elephant is in the left of person
# elephant is in the right of person
# elephant is in the right of person
# person is in the right of person
# person is in the right of person

# %%
for i in range(len(x_values)):
    for j in range(i + 1, len(x_values)):
        if y_values[i]>y_values[j] and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"is in the bottom of",object_name_list[j])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[8])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[9])
            object_2.append(object_name_list[i])            
        elif y_values[i]<y_values[j] and Image_name_list[i]==Image_name_list[j]:
            print(object_name_list[i],"is in the top of",object_name_list[j])
            
            object_1.append(object_name_list[i]) 
            imageName.append(Image_name_list[i])
            predicate.append(relations[9])
            object_2.append(object_name_list[j])

            object_1.append(object_name_list[j]) 
            imageName.append(Image_name_list[j])
            predicate.append(relations[8])
            object_2.append(object_name_list[i])
# Out:
# cat is in the bottom of cup
# elephant is in the bottom of elephant
# elephant is in the top of cow
# elephant is in the bottom of elephant
# elephant is in the top of cow
# elephant is in the top of cow
# elephant is in the bottom of cow
# elephant is in the top of elephant
# elephant is in the bottom of elephant
# elephant is in the top of elephant
# cow is in the bottom of elephant
# cow is in the top of cow
# cow is in the top of cow
# cow is in the bottom of cow
# cow is in the top of elephant
# cow is in the bottom of elephant
# cow is in the top of elephant
# elephant is in the top of cow
# elephant is in the top of cow
# elephant is in the top of cow
# elephant is in the top of elephant
# elephant is in the top of elephant
# elephant is in the top of elephant
# cow is in the top of cow
# cow is in the bottom of cow
# cow is in the bottom of elephant
# cow is in the bottom of elephant
# cow is in the top of elephant
# cow is in the bottom of cow
# cow is in the bottom of elephant
# cow is in the bottom of elephant
# cow is in the top of elephant
# cow is in the top of elephant
# cow is in the top of elephant
# elephant is in the bottom of elephant
# elephant is in the top of elephant
# elephant is in the top of elephant
# elephant is in the top of elephant
# elephant is in the top of car
# elephant is in the top of elephant
# car is in the bottom of elephant
# car is in the bottom of dog
# elephant is in the top of car
# car is in the bottom of car
# person is in the top of car
# bus is in the bottom of traffic light
# bus is in the top of person
# elephant is in the top of truck
# elephant is in the top of car
# elephant is in the top of truck
# elephant is in the top of car
# truck is in the top of car
# truck is in the top of truck
# truck is in the top of car
# car is in the bottom of truck
# car is in the bottom of car
# truck is in the top of car
# person is in the bottom of car
# person is in the bottom of elephant
# person is in the bottom of person
# person is in the bottom of person
# person is in the bottom of person
# car is in the bottom of elephant
# car is in the top of person
# car is in the top of person
# car is in the top of person
# elephant is in the top of person
# elephant is in the top of person
# elephant is in the top of person
# person is in the bottom of person
# person is in the bottom of person
# person is in the bottom of person

# %%
af = pd.DataFrame(data={"object_1": object_1, "relations": predicate, "object_2": object_2,"image_Name":imageName})
af.to_csv("./farClose2.csv", sep=',',index=False)
